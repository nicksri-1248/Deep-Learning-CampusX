# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
# Out:
# 2026-06-13 12:28:05.073220: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781353685.406392      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781353685.501440      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781353686.291448      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
model = ResNet50(weights = 'imagenet')
# Out:
# 2026-06-13 12:28:25.865267: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
img_path = '/kaggle/input/datasets/nicksri1248/sample-50-pretrianed/tomato.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n07768694', 'pomegranate', np.float32(0.63957644)), ('n04476259', 'tray', np.float32(0.2391507)), ('n07720875', 'bell_pepper', np.float32(0.06889912))]

# %%
img_path = '/kaggle/input/datasets/nicksri1248/sample-50-pretrianed/dog.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Predicted: [('n02099601', 'golden_retriever', np.float32(0.84427106)), ('n02113799', 'standard_poodle', np.float32(0.0445036)), ('n02111500', 'Great_Pyrenees', np.float32(0.03339491))]

# %%
img_path = '/kaggle/input/datasets/nicksri1248/sample-50-pretrianed/bread.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Predicted: [('n07684084', 'French_loaf', np.float32(0.82214123)), ('n04442312', 'toaster', np.float32(0.08437743)), ('n07693725', 'bagel', np.float32(0.026964352))]

# %%
img_path = '/kaggle/input/datasets/nicksri1248/sample-50-pretrianed/chair.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top = 3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Predicted: [('n03201208', 'dining_table', np.float32(0.59027535)), ('n04099969', 'rocking_chair', np.float32(0.09857992)), ('n03179701', 'desk', np.float32(0.07839864))]
